# %%
import shutil
import os

checkpoint_path = "streaming/checkpoint"
if os.path.exists(checkpoint_path):
    shutil.rmtree(checkpoint_path)
    print("Checkpoint cleared!")
# Out:
# Checkpoint cleared!
